# %%
import numpy as np
import rasters as rt
import modland
from koppengeiger import load_koppen_geiger

# %%
global_land_cover = load_koppen_geiger()
global_land_cover

# %%
geometry = modland.generate_modland_grid(8, 5, 2400)
geometry
# Out:
# {
#   "dimensions": {
#     "rows": 2400,
#     "cols": 2400
#   },
#   "bbox": {
#     "xmin": -11119505.197665555,
#     "ymin": 3335851.5592996655,
#     "xmax": -10007554.677899,
#     "ymax": 4447802.079066221
#   },
#   "crs": "+proj=sinu +lon_0=0 +x_0=0 +y_0=0 +R=6371007.181 +units=m +no_defs +type=crs",
#   "resolution": {
#     "cell_width": 463.3127165693981,
#     "cell_height": -463.3127165693981
#   }
# }

# %%
land_cover = load_koppen_geiger(geometry)
land_cover
